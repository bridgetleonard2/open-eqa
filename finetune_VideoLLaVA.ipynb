# %%
import pandas as pd
import numpy as np
import os
from PIL import Image

# %%
# Load the training data
data = pd.read_csv('spatial_hm3d_responses.csv')

# %%
# Select image history, question answer column
train_data = data[['question', 'answer', 'episode_history']]

# %%
train_data
# Out:
#                                              question  \
# 0   What is in between the two picture frames on t...
# 1           Is there room on the dining table to eat?
# 2                  What is to the left of the mirror?
# 3               What is to the left of the staircase?
# 4   What is on the top shelf to the right side of ...
# ..                                                ...
# 64  Is there space for another pillow on the back ...
# 65                 Where is the "Be Thankful" poster?
# 66                Where is "Bless this home" written?
# 67           What is on the opposite wall of the bed?
# 68         What's below the window of the front door?
#
#                             answer               episode_history
# 0                           The TV  hm3d-v0/000-hm3d-BFRyYbPCCPE
# 1                              Yes  hm3d-v0/000-hm3d-BFRyYbPCCPE
# 2           A plant in a tall vase  hm3d-v0/001-hm3d-TPhiubUHKcP
# 3                 A storage closet  hm3d-v0/001-hm3d-TPhiubUHKcP
# 4                    An ice cooler  hm3d-v0/002-hm3d-wcojb4TFT35
# ..                             ...                           ...
# 64                              No  hm3d-v0/094-hm3d-Qpor2mEya8F
# 65                Above the stairs  hm3d-v0/096-hm3d-uLz9jNga3kC
# 66  Above the dinner room entrance  hm3d-v0/096-hm3d-uLz9jNga3kC
# 67                              TV  hm3d-v0/099-hm3d-q5QZSEeHe5g
# 68                       mailslot   hm3d-v0/099-hm3d-q5QZSEeHe5g
#
# [69 rows x 3 columns]

# %% [markdown]
# ## Prepare training data

# %%
def load_images_to_array(directory):
    # List all PNG files in the directory
    files = [f for f in sorted(os.listdir(directory)) if f.endswith('.png')]
    images = []
    
    # Loop through files and load each image
    for file in files:
        # Construct full file path
        file_path = os.path.join(directory, file)
        # Open the image file
        with Image.open(file_path) as img:
            # Convert the image to RGB (if not already in that format)
            img = img.convert('RGB')
            # Convert the image to a NumPy array and append to list
            images.append(np.array(img))
    
    video = np.stack(images)
    total_frames = video.shape[0]

    indices = np.arange(0, total_frames, total_frames / 8).astype(int)  # np.linspace(0, total_frames - 1, num=8, dtype=int)
    print("Number of frames: ", total_frames)
    print("Selected indices: ", indices)
    images = [video[i] for i in indices]
    # Stack all image arrays into a single numpy array
    return np.stack(images)

# %%
def json_item(image, question, answer, index):
    new_item = {
        "id": f"{index:03}",  # Formats index leading zeros
        "image": image,
        "conversations": [
            {
                "from": "human",
                "value": f"\n{question}"
            },
            {
                "from": "gpt",
                "value": answer
            }
        ]
    }
    return new_item

# %%
train_json = []

for index, row in train_data.iterrows():
    question = row['question']
    answer = row['answer']
    ep_history = row['episode_history']
    episode_history = f"data/frames/{ep_history}"
    images = load_images_to_array(episode_history)
    train_json.append(json_item(images, question, answer, index))
# Out:
# Number of frames:  99
# Selected indices:  [ 0 12 24 37 49 61 74 86]
# Number of frames:  99
# Selected indices:  [ 0 12 24 37 49 61 74 86]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  82
# Selected indices:  [ 0 10 20 30 41 51 61 71]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  100
# Selected indices:  [ 0 12 25 37 50 62 75 87]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  82
# Selected indices:  [ 0 10 20 30 41 51 61 71]
# Number of frames:  82
# Selected indices:  [ 0 10 20 30 41 51 61 71]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  109
# Selected indices:  [ 0 13 27 40 54 68 81 95]
# Number of frames:  109
# Selected indices:  [ 0 13 27 40 54 68 81 95]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  342
# Selected indices:  [  0  42  85 128 171 213 256 299]
# Number of frames:  342
# Selected indices:  [  0  42  85 128 171 213 256 299]
# Number of frames:  175
# Selected indices:  [  0  21  43  65  87 109 131 153]
# Number of frames:  113
# Selected indices:  [ 0 14 28 42 56 70 84 98]
# Number of frames:  113
# Selected indices:  [ 0 14 28 42 56 70 84 98]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  261
# Selected indices:  [  0  32  65  97 130 163 195 228]
# Number of frames:  261
# Selected indices:  [  0  32  65  97 130 163 195 228]
# Number of frames:  351
# Selected indices:  [  0  43  87 131 175 219 263 307]
# Number of frames:  351
# Selected indices:  [  0  43  87 131 175 219 263 307]
# Number of frames:  291
# Selected indices:  [  0  36  72 109 145 181 218 254]
# Number of frames:  291
# Selected indices:  [  0  36  72 109 145 181 218 254]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  400
# Selected indices:  [  0  50 100 150 200 250 300 350]
# Number of frames:  319
# Selected indices:  [  0  39  79 119 159 199 239 279]
# Number of frames:  319
# Selected indices:  [  0  39  79 119 159 199 239 279]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  120
# Selected indices:  [  0  15  30  45  60  75  90 105]
# Number of frames:  330
# Selected indices:  [  0  41  82 123 165 206 247 288]
# Number of frames:  330
# Selected indices:  [  0  41  82 123 165 206 247 288]
# Number of frames:  293
# Selected indices:  [  0  36  73 109 146 183 219 256]
# Number of frames:  293
# Selected indices:  [  0  36  73 109 146 183 219 256]
# Number of frames:  108
# Selected indices:  [ 0 13 27 40 54 67 81 94]
# Number of frames:  291
# Selected indices:  [  0  36  72 109 145 181 218 254]
# Number of frames:  299
# Selected indices:  [  0  37  74 112 149 186 224 261]
# Number of frames:  299
# Selected indices:  [  0  37  74 112 149 186 224 261]
# Number of frames:  205
# Selected indices:  [  0  25  51  76 102 128 153 179]
# Number of frames:  205
# Selected indices:  [  0  25  51  76 102 128 153 179]
# Number of frames:  302
# Selected indices:  [  0  37  75 113 151 188 226 264]
# Number of frames:  302
# Selected indices:  [  0  37  75 113 151 188 226 264]

# %%
# Save json
import json
with open('train.json', 'w') as f:
    json.dump(train_json, f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       2 import json
#       3 with open('train.json', 'w') as f:
# ----> 4     json.dump(train_json, f)
#
# File c:\Users\Bridget Leonard\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File c:\Users\Bridget Leonard\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:430, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     428     yield _floatstr(o)
#     429 elif isinstance(o, (list, tuple)):
# --> 430     yield from _iterencode_list(o, _current_indent_level)
#     431 elif isinstance(o, dict):
#     432     yield from _iterencode_dict(o, _current_indent_level)
#
# File c:\Users\Bridget Leonard\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:326, in _make_iterencode.<locals>._iterencode_list(lst, _current_indent_level)
#     324         else:
#     325             chunks = _iterencode(value, _current_indent_level)
# --> 326         yield from chunks
#     327 if newline_indent is not None:
#     328     _current_indent_level -= 1
#
# File c:\Users\Bridget Leonard\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File c:\Users\Bridget Leonard\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:439, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     437         raise ValueError("Circular reference detected")
#     438     markers[markerid] = o
# --> 439 o = _default(o)
#     440 yield from _iterencode(o, _current_indent_level)
#     441 if markers is not None:
#
# File c:\Users\Bridget Leonard\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type ndarray is not JSON serializable

# %% [markdown]
# ## Set up metrics
# We'll use Exact Match and F1-score since this is a question answering task

# %%
from sklearn.metrics import f1_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)

    em = sum([1 if p == l else 0 for p, l in zip(preds, labels)]) / len(labels)
    f1 = f1_score(labels, preds, average='macro')
    return {
        'exact_match': em,
        'f1': f1,
    }

# %% [markdown]
# ## Fine-tune the model

# %%
from transformers import Trainer, TrainingArguments, VideoLlavaForConditionalGeneration, VideoLlavaProcessor

# load the model
model = VideoLlavaForConditionalGeneration.from_pretrained("LanguageBind/Video-LLaVA-7B-hf", device_map="auto")

# define training arguments
training_args = TrainingArguments(
    output_dir="./finetune_results",
    evaluation_strategy="epoch",
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    num_train_epochs=3,
    save_total_limit=2,
    save_steps=500,
    logging_dir="./logs",
    load_best_model_at_end=True,
    push_to_hub=False,
)

# create trainer
trainer = Trainer(
    model=model,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset
